# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\lrnovo\Desktop\PROJECT\HR_Attrition\HR-Employee-Attrition 1.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ## Basic Analysis

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.961224   802.485714          9.192517     2.912925            1.0
# std       9.312179   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max     108.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    66.006803        2.729932
# ...

# %%
df.describe().plot()
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1468 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              2
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 20     24        No     Non-Travel        673  Research & Development
# 1459   29        No  Travel_Rarely       1378  Research & Development
# 1463   31        No     Non-Travel        325  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 20                  11          2            NaN              1
# 1459                13          2          Other              1
# 1463                 5          3            NaN              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 20                26  ...                         4            80
# 1459            2053  ...                         1            80
# 1463            2057  ...                         2            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 20                   1                  5                      5
# ...

# %% [markdown]
# ## Let's First deal with Education Field, Null Value with Other

# %%
df['EducationField']=df['EducationField'].fillna('Other')

# %%
df[df.isnull().any(axis=1)]
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 1459   29        No  Travel_Rarely       1378  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1459                13          2          Other              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 1459            2053  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1459                 1                 10                      2
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 1459               3               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 1459                        0                     3
#
# [1 rows x 35 columns]

# %%
row1= df.iloc[1459]  ## using this we can find that NaN value (job role -- NAN)
row1
# Out:
# Age                                             29
# Attrition                                       No
# BusinessTravel                       Travel_Rarely
# DailyRate                                     1378
# Department                  Research & Development
# DistanceFromHome                                13
# Education                                        2
# EducationField                               Other
# EmployeeCount                                    1
# EmployeeNumber                                2053
# EnvironmentSatisfaction                          4
# Gender                                        Male
# HourlyRate                                      46
# JobInvolvement                                   2
# JobLevel                                         2
# JobRole                                        NaN
# JobSatisfaction                                  2
# MaritalStatus                              Married
# ...

# %% [markdown]
# ## Now Job RoLe Column ,and will fil the NAN value with 'Research Scientist'

# %%
## first method ----   df['JobRole']=df['JobRole'].fillna('Research Scientist')  
## second method ----  ffill and bfill method 

df['JobRole']=df['JobRole'].fillna(method='bfill')

# %%
df[df.isnull().any(axis=1)]    ## now it will give zero NaN value
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# ##  Duplicate Value

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Let's Deal With Outliers

# %% [markdown]
# ## To find outliers there are three method ( z score , box plot , domain knowledge )

# %%
df1= df.copy()
df1
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
 from scipy import stats

# %%
z_score = stats.zscore(df1['Age'])
threshold = 3

outliers = (z_score > threshold ) | (z_score < - threshold )
outliers
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Name: Age, Length: 1470, dtype: bool

# %%
df[outliers == True]
# Out:
#      Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 502  108        No  Travel_Rarely        238      Sales                 1
#
#      Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 502          1        Medical              1             682  ...
#
#      RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 502                         4            80                 0
#
#      TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 502                 18                      2               4              14
#
#     YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 502                  7                        8                    10
#
# [1 rows x 35 columns]

# %%
outlier_rows = df[outliers]
outlier_rows
# Out:
#      Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 502  108        No  Travel_Rarely        238      Sales                 1
#
#      Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 502          1        Medical              1             682  ...
#
#      RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 502                         4            80                 0
#
#      TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 502                 18                      2               4              14
#
#     YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 502                  7                        8                    10
#
# [1 rows x 35 columns]

# %%
import seaborn as sns

# %%
sns.boxplot(df1['Age'])
# Out:
# <Axes: >

# %% [markdown]
# ## lets first seprate the numericals column and non-nuerical column

# %%
numerical_col = df1.select_dtypes(include=['number']).columns
numerical_col
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
numerical_col = df1.select_dtypes(include=['number']).columns.tolist()
categorical_col = df1.select_dtypes(include=['object']).columns.tolist()
print(numerical_col)
print(categorical_col)
# Out:
# ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
# ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']

# %%
import matplotlib.pyplot as plt

# %%
fig ,axes= plt.subplots(nrows=len(numerical_col),ncols =1 , figsize=(10,6*len(numerical_col)))
for i ,col in enumerate(numerical_col):
    sns.boxplot(x=df1[col] , ax=axes[i])
    z_score = stats.zscore(df1[col])
    threshold = 3
    outlier_indices = (z_score >threshold) | (z_score <-threshold)
    df2=df1[~outlier_indices]
plt.tight_layout()    
plt.show()

# %%
df2
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # save the Data

# %%
# save this data
df2.to_csv('HR_Attrition_cleaned_Data.csv',index=False)

# %% [markdown]
# # Dump Data to Sql

# %%
import mysql.connector
from mysql.connector import Error

# %%
try:
    connection = mysql.connector.connect(host= 'localhost',
                           database= 'hr_Attrition',
                           user= 'root',
                           password= '3693')
    if connection.is_connected():
        db_info= connection.get_server_info()
        print(db_info)
except Error as e:
        print("Somethig wrong",e)
# Out:
# 8.0.35

# %%
df2.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df2.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df2.values
# Out:
# array([[41, 'Yes', 'Travel_Rarely', ..., 4, 0, 5],
#        [49, 'No', 'Travel_Frequently', ..., 7, 1, 7],
#        [37, 'Yes', 'Travel_Rarely', ..., 0, 0, 0],
#        ...,
#        [27, 'No', 'Travel_Rarely', ..., 2, 0, 3],
#        [49, 'No', 'Travel_Frequently', ..., 6, 0, 8],
#        [34, 'No', 'Travel_Rarely', ..., 3, 1, 2]], dtype=object)

# %%
data_mapping = {'int64':'INT','object':'TEXT'}
cursor= connection.cursor()

# %%
columns= ",".join([f'{col} {data_mapping[str(df2[col].dtype)]}' for col in df2.columns])
columns
# Out:
# 'Age INT,Attrition TEXT,BusinessTravel TEXT,DailyRate INT,Department TEXT,DistanceFromHome INT,Education INT,EducationField TEXT,EmployeeCount INT,EmployeeNumber INT,EnvironmentSatisfaction INT,Gender TEXT,HourlyRate INT,JobInvolvement INT,JobLevel INT,JobRole TEXT,JobSatisfaction INT,MaritalStatus TEXT,MonthlyIncome INT,MonthlyRate INT,NumCompaniesWorked INT,Over18 TEXT,OverTime TEXT,PercentSalaryHike INT,PerformanceRating INT,RelationshipSatisfaction INT,StandardHours INT,StockOptionLevel INT,TotalWorkingYears INT,TrainingTimesLastYear INT,WorkLifeBalance INT,YearsAtCompany INT,YearsInCurrentRole INT,YearsSinceLastPromotion INT,YearsWithCurrManager INT'

# %%
cursor.execute(f'create table if not exists hr_data ({columns})')

# %%
data= [tuple(i) for i in df2.values]
data
# Out:
# [(41,
#   'Yes',
#   'Travel_Rarely',
#   1102,
#   'Sales',
#   1,
#   2,
#   'Life Sciences',
#   1,
#   1,
#   2,
#   'Female',
#   94,
#   3,
#   2,
#   'Sales Executive',
#   4,
#   'Single',
#   5993,
#   19479,
#   8,
#   'Y',
#   'Yes',
#   11,
#   3,
#   1,
#   80,
#   0,
#   8,
#   0,
#   1,
#   6,
#   4,
#   0,
#   5),
#  (49,
#   'No',
#   'Travel_Frequently',
#   279,
#   'Research & Development',
#   8,
#   1,
#   'Life Sciences',
#   1,
#   2,
#   3,
#   'Male',
#   61,
#   2,
#   2,
#   'Research Scientist',
#   2,
#   'Married',
#   5130,
#   24907,
#   1,
#   'Y',
#   'No',
#   23,
#   4,
#   4,
#   80,
#   1,
#   10,
#   3,
#   3,
#   10,
#   7,
#   1,
#   7),
#  (37,
#   'Yes',
#   'Travel_Rarely',
#   1373,
#   'Research & Development',
#   2,
#   2,
#   'Other',
#   1,
#   4,
#   4,
#   'Male',
#   92,
#   2,
#   1,
#   'Laboratory Technician',
#   3,
#   'Single',
#   2090,
#   2396,
#   6,
#   'Y',
#   'Yes',
#   15,
#   3,
#   2,
#   80,
#   0,
#   7,
#   3,
# ...

# %%
type(data)
# Out:
# list

# %%
cursor.executemany(f"insert into hr_data values ({','.join(['%s']* len(df2.columns))})", data)

# %%
connection.commit()

# %%
# cursor.close()
# connection.close()    use to close the connection
